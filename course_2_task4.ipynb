# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,10,21)
x1 = np.linspace(0,10,70)
plt.plot(x,np.cos(x), marker='o')
plt.plot(x1,np.cos(8*x1))
print(x)
# Out:
# [ 0.   0.5  1.   1.5  2.   2.5  3.   3.5  4.   4.5  5.   5.5  6.   6.5
#   7.   7.5  8.   8.5  9.   9.5 10. ]
